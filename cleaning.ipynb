# %%
import pandas as pd

# %%
df = pd.read_csv('input.csv')
df[df['Longitudes'].isna()]
# Out:
#                                            Business Name  \
# 10                                 Millcroft Inn and spa
# 285                                   Aldea Gowsell, RMT
# 494                                    Alisha Jiwan, RMT
# 688                                     Amanda Ennis RMT
# 2132                            Scandinave Blue Mountain
# 2508                              Cassandra Clayton, RMT
# 2535                            Catherine D. Battah, RMT
# 2665                           Complete Integrative Care
# 2819                               Cherry-Ann James, RMT
# 3392                        Corina Jacqueline Latta, RMT
# 3689                                 Millcroft Inn & Spa
# 3759                                    DANTING XUE, RMT
# 4020                          Demetra (Deme) Barlas, RMT
# 4375                        AMBA Spa At Windermere House
# 6487                                       St Anne's Spa
# ...
